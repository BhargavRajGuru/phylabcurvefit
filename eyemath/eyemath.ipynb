# %%
from pylab import *
import modules.eyemath17 as em


NP=50

r=2*ranf(NP)-1

print(r)

x=linspace(0,10,NP)
data=(2+r)+3*x

y,par=em.fit_line(x,data)

print(par)

plot(x,data,'ob')
plot(x,y)
# Out:
# [-0.34385522 -0.46700617  0.11823814 -0.35968689 -0.46728191  0.00234906
#  -0.416675    0.151901   -0.97866655  0.25351554 -0.7860028   0.19385129
#   0.74128749  0.06543261 -0.12062905  0.65167407  0.39329776  0.28201586
#   0.25129782  0.65158593 -0.24740195  0.3900644   0.3152388   0.07549211
#   0.42470762  0.2814061   0.74272342 -0.20809132  0.70764788 -0.23558577
#  -0.33806875  0.74078407  0.36584231 -0.6861022   0.81568852 -0.2123088
#  -0.86307218  0.58688597  0.91977276 -0.30894155  0.7526012   0.24089504
#  -0.8732593   0.6371169   0.73926235  0.55239752 -0.01556288 -0.86686424
#   0.9402992  -0.49635085]
# [3.03479483 1.91990302]
