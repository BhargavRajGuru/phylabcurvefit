# %%
from pylab import *
import modules.eyemath17 as em


NP=50

r=2*ranf(NP)-1

print(r)

x=linspace(0,10,NP)
data=(2+r)+3*x

y,par=em.fit_line(x,data)

print(par)

plot(x,data,'ob')
plot(x,y)
# Out:
# [-1.90726213e-01  6.92383799e-01  6.15554747e-01  8.77471380e-01
#   5.34364294e-01  8.94956084e-01  8.79321278e-01 -2.09872245e-01
#   2.47940492e-01  4.33248558e-04 -8.01651407e-01  2.58843167e-01
#  -1.34674867e-01  1.58055967e-01 -4.30035193e-01 -7.29204256e-01
#   4.52306463e-01 -9.78533831e-01 -7.60367821e-02 -7.36057831e-01
#  -4.68583252e-01  7.93881844e-01 -8.57955709e-01  3.01546960e-01
#   2.05921849e-01  6.38138057e-01  9.52481491e-01  7.32948950e-01
#  -1.63448815e-01  7.68486960e-01  4.18577993e-01 -7.07532765e-02
#  -8.36356968e-01  7.76482055e-01  5.79347393e-01 -6.44682975e-01
#   5.67141205e-02  5.33543268e-01  3.41386692e-01 -9.33755192e-01
#  -5.67329362e-01 -8.99155360e-01  2.54519683e-01 -9.64179816e-01
#   6.70062247e-01 -2.89906807e-01 -5.88697180e-01 -8.74236036e-01
#   7.55911574e-01  4.83833883e-01]
# [2.95865627 2.25531032]
